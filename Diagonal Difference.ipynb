# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %%
def diagonalDifference(arr):
    temp = 0
    emp = 0
    for i in range(0,len(arr)):
        temp = temp + arr[i][i]
    
    for j in range(0,len(arr)):
        emp = emp + arr[j][len(arr)-1-j]
    
    return abs(temp - emp)
print(diagonalDifference([[5,2,7],[4,1,6],[3,8,9]]))
# Out:
# 4
