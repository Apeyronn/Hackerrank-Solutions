# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
def lonelyinteger(a):
    # Write your code here
    a = sorted(a)
    if len(a) < 3:
        return a[0]
    elif a[0] != a[1]:
        return a[0]
    else:
        return lonelyinteger(a[2:])
print(lonelyinteger([1,2,3,2,1,4,5,4,5]))
# Out:
# 3
