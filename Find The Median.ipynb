# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
def findMedian(arr):
    n = len(arr)
    arr.sort()
    median = arr[n//2]
    return median
print(findMedian([0,1,2,3,4,5]))
# Out:
# 3
